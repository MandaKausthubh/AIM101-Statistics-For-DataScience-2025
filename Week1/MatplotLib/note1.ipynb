# %% [markdown]
# # Notebook 1: Introduction to Matplotlib Concepts

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ### Creating basic line plot

# %%
x = [1, 2, 3, 4, 5]
y = [2, 3, 5, 7, 11]
plt.plot(x, y)
plt.title("Basic Line Plot")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.show()

# %% [markdown]
# ### Scatter plot

# %%
plt.scatter(x, y, color='red')
plt.title("Basic Scatter Plot")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.show()

# %% [markdown]
# ### Bar chart

# %%
categories = ['A', 'B', 'C', 'D', 'E']
values = [3, 7, 8, 5, 10]
plt.bar(categories, values)
plt.title("Basic Bar Chart")
plt.show()

# %% [markdown]
# ### Histograms

# %%
import numpy as np
data = np.random.randn(1000)
plt.hist(data, bins=40, color='blue', alpha=0.3)
plt.title("Histogram")
plt.show()

# %% [markdown]
# ### Pie chart

# %%
labels = ['A', 'B', 'C', 'D']
sizes = [15, 30, 45, 10]
plt.pie(sizes, labels=labels, autopct='%1.1f%%')
plt.title("Pie Chart")
plt.show()
